# %%
from bts.data import load_data, load_atbats, load_pitches

# %%
data = load_data()
atbats = load_atbats()
pitches = load_pitches()

# %%
pitches
# Out:
#         game_pk  game_date game_year            batter       pitcher  \
# 0        263816 2010-04-04      2010       Derek Jeter  Josh Beckett
# 1        263816 2010-04-04      2010      Nick Johnson  Josh Beckett
# 2        263816 2010-04-04      2010      Nick Johnson  Josh Beckett
# 3        263816 2010-04-04      2010      Nick Johnson  Josh Beckett
# 4        263816 2010-04-04      2010      Nick Johnson  Josh Beckett
# ...         ...        ...       ...               ...           ...
# 8104863  632254 2021-10-03      2021     Brandon Nimmo    Will Smith
# 8104864  632254 2021-10-03      2021  Francisco Lindor    Will Smith
# 8104865  632254 2021-10-03      2021  Francisco Lindor    Will Smith
# 8104866  632254 2021-10-03      2021  Francisco Lindor    Will Smith
# 8104867  632254 2021-10-03      2021  Francisco Lindor    Will Smith
#
#         pitch_type  release_speed  release_pos_x  release_pos_z     events  \
# ...
